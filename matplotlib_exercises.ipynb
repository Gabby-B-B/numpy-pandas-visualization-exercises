# %% [markdown]
# Use matplotlib to plot the following equation:
#
# y=x2−x+2
# You'll need to write the code that generates the x and y points.
#
# Add an anotation for the point 0, 0, the origin.

# %%
import matplotlib.pyplot as plt
import math

# %%
x= list(range(-20, 20))
y= [(c ** c -(c +2)) for c in x]
plt.title('(x^2)-x+2')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.plot(x,y)
plt.ylim(-10, 50)
plt.xlim(-10, 10)
plt.annotate('Origin', xy=(0, 0), xytext=(-3, 5),
             arrowprops={'facecolor': 'pink'})
# Out:
# Text(-3, 5, 'Origin')

# %% [markdown]
# Create and label 4 separate charts for the following equations (choose a range for x that makes sense):
#
# y=√x
# y=x3
# y=2x
# You can use functions from the math module to help implement some of the equations above.

# %%
# Square Root
plt.title("Square Root")
plt.xlabel('X')
plt.ylabel('Square Root of X')
x= list(range (1,20))
y= [(c ** 0.5) for c in x]
plt.plot(x,y)

# %%
# Cubed
plt.title("Cubed")
plt.xlabel('X')
plt.ylabel('X Cubed')
x= list(range(-20, 20))
y= [(c**3) for c in x]
plt.plot(x,y)

# %%
# Times two
plt.title("Double")
plt.xlabel('X')
plt.ylabel('X times 2')
x= list(range(-20, 20))
y= [(2**c) for c in x]
plt.plot(x,y)

# %%
# all combined
x= [1,2,3,4,5]
y1= [(n ** 0.5) for n in x]
y2= [(n ** 3) for n in x]
y3= [(2 ** n) for n in x]
y4= [(n ** n -(n +2)) for n in x]
plt.title('All equations combined.')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x, y3)
plt.plot(x, y4)
plt.xlim(1, 3)
plt.ylim(1, 25)
# Out:
# (1, 25)
