# %% [markdown]
# Make a new Jupyter notebook named big_o_notation.ipynb
#
# Title your chart "Big O Notation"
# Label your x axis "Elements"
# Label your y axis "Operations"
# Label your curves or make a legend for the curves
# Use LaTex notation where possible
# Curves to graph
#
# y=0x+1 and label the curve "O(1)"
# y=log(x) and label the curve "O(log n)"
# y= x and label the curve "O(n)"
# y = x ∗ log(x) and label it "O(n log n)"
# y = x 2 and label it "O(n^2)"
# y = 2x and label it "O(2^n)"
# y = n! and label it "O(n!)"
# y= n^n and label it "O(n^n)"
# Bonus Write the code necessary to write your name on a chart. Use box letters.
#
# Bonus: use curves for letters in your name that have curves in them.

# %%
import matplotlib.pyplot as plt
import math

# %%
plt.title('Big O Notation')
plt.xlabel('Elements')
plt.ylabel('Operations')

x1= [1,2,3,4,5]
y1= [((0*n)+1) for n in x1]
plt.plot(x1, y1, c='teal', label= 'O(1)')


x2= [1, 2, 3]
y2= [math.log(n) for n in x2]
plt.plot(x2, y2, c='fuchsia', label= 'O $log n$')

x3= range(1,6)
y3= [n*1 for n in x3]
plt.plot(x3, y3, c='lightblue', label= 'O(n)')

x4= [1,2,3,4]
y4= [(n * math.log(n)) for n in x4]
plt.plot(x4, y4, c='darkmagenta', label='O n $\log n$')

x5= [1,2,3,4]
y5= [(n**2) for n in x5]
plt.plot(x5, y5, c='orchid', label = 'O(n^2)')

x6=[1,2,3,4]
y6= [(2**n) for n in x6]
plt.plot(x6, y6, c='turquoise', label='O(2^n)')

x7=[1,2,3]
y7= [math.factorial(n) for n in x7]
plt.plot(x7, y7, c='cornflowerblue', label='O(n!)')

x8=[1,2,3]
y8= [(n**n) for n in x8]
plt.plot(x8, y8, c='mediumblue', label='O n^n')

plt.ylim(-1, 16)
plt.xlim(1, 4)

plt.legend(loc='upper left')
